# %%
import fastf1
cache_location = 'C:\\Users\\Ahmed Essam\\development\\AI\\F1\\f1cache'
fastf1.Cache.enable_cache(cache_location)
grand_prix = 'Suzuka'
current_year = 2025
previous_year = current_year - 1

# %%
# Load FastF1 2024 GP race session
session_2024 = fastf1.get_session(previous_year, grand_prix, "R")
session_2024.load()
# Out:
# core           INFO 	Loading data for Japanese Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '55', '16', '4', '14', '63', '81', '44', '22', '27', '18', '20', '77', '31', '10', '2', '24', '3', '23']
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '55', '16', '4', '14', '63', '81', '44', '22', '27', '18', '20', '77', '31', '10', '2', '24', '3', '23']

# %%
session_2024.results.info()
session_2024.results.head(5)
# Out:
# <class 'fastf1.core.SessionResults'>
# Index: 20 entries, 1 to 23
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        20 non-null     object
#  1   BroadcastName       20 non-null     object
#  2   Abbreviation        20 non-null     object
#  3   DriverId            20 non-null     object
#  4   TeamName            20 non-null     object
#  5   TeamColor           20 non-null     object
#  6   TeamId              20 non-null     object
#  7   FirstName           20 non-null     object
#  8   LastName            20 non-null     object
#  9   FullName            20 non-null     object
#  10  HeadshotUrl         20 non-null     object
#  11  CountryCode         20 non-null     object
#  12  Position            20 non-null     float64
#  13  ClassifiedPosition  20 non-null     object
#  14  GridPosition        20 non-null     float64
#  15  Q1                  0 non-null      timedelta64[ns]
#  16  Q2                  0 non-null      timedelta64[ns]
#  17  Q3                  0 non-null      timedelta64[ns]
#  18  Time                17 non-null     timedelta64[ns]
#  19  Status              20 non-null     object
#  20  Points              20 non-null     float64
# dtypes: float64(3), object(14), timedelta64[ns](4)
# memory usage: 3.4+ KB
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 11           11       S PEREZ          PER           perez  Red Bull Racing
# 55           55       C SAINZ          SAI           sainz          Ferrari
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 4             4      L NORRIS          NOR          norris          McLaren
#
#    TeamColor    TeamId FirstName    LastName         FullName  ...  \
# 1     3671C6  red_bull       Max  Verstappen   Max Verstappen  ...
# 11    3671C6  red_bull    Sergio       Perez     Sergio Perez  ...
# 55    E80020   ferrari    Carlos       Sainz     Carlos Sainz  ...
# 16    E80020   ferrari   Charles     Leclerc  Charles Leclerc  ...
# 4     FF8000   mclaren     Lando      Norris     Lando Norris  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  Q1  Q2  Q3  \
# 1          NED      1.0                   1          1.0 NaT NaT NaT
# 11         MEX      2.0                   2          2.0 NaT NaT NaT
# 55         ESP      3.0                   3          4.0 NaT NaT NaT
# 16         MON      4.0                   4          8.0 NaT NaT NaT
# 4          GBR      5.0                   5          3.0 NaT NaT NaT
#
#                      Time    Status Points
# 1  0 days 01:54:23.566000  Finished   26.0
# 11 0 days 00:00:12.535000  Finished   18.0
# 55 0 days 00:00:20.866000  Finished   15.0
# 16 0 days 00:00:26.522000  Finished   12.0
# 4  0 days 00:00:29.700000  Finished   10.0
#
# [5 rows x 21 columns]

# %%
quali_2025 = fastf1.get_session(current_year, grand_prix, "Q")
quali_2025.load()
quali_2024 = fastf1.get_session(previous_year, grand_prix, "Q")
quali_2024.load()
# Out:
# core           INFO 	Loading data for Japanese Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '81', '16', '63', '12', '6', '44', '23', '87', '10', '55', '14', '30', '22', '27', '5', '31', '7', '18']
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '81', '16', '63', '12', '6', '44', '23', '87', '10', '55', '14', '30', '22', '27', '5', '31', '7', '18']
# core           INFO 	Loading data for Japanese Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# core           INFO 	Loading data for Japanese Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '4', '55', '14', '81', '44', '16', '63', '22', '3', '27', '77', '23', '31', '18', '10', '20', '2', '24']
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '4', '55', '14', '81', '44', '16', '63', '22', '3', '27', '77', '23', '31', '18', '10', '20', '2', '24']

# %%
quali_2025.results.info()
quali_2025.results.head(5)
# Out:
# <class 'fastf1.core.SessionResults'>
# Index: 20 entries, 1 to 18
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        20 non-null     object
#  1   BroadcastName       20 non-null     object
#  2   Abbreviation        20 non-null     object
#  3   DriverId            20 non-null     object
#  4   TeamName            20 non-null     object
#  5   TeamColor           20 non-null     object
#  6   TeamId              20 non-null     object
#  7   FirstName           20 non-null     object
#  8   LastName            20 non-null     object
#  9   FullName            20 non-null     object
#  10  HeadshotUrl         20 non-null     object
#  11  CountryCode         20 non-null     object
#  12  Position            20 non-null     float64
#  13  ClassifiedPosition  20 non-null     object
#  14  GridPosition        0 non-null      float64
#  15  Q1                  20 non-null     timedelta64[ns]
#  16  Q2                  15 non-null     timedelta64[ns]
#  17  Q3                  10 non-null     timedelta64[ns]
#  18  Time                0 non-null      timedelta64[ns]
#  19  Status              20 non-null     object
#  20  Points              0 non-null      float64
# dtypes: float64(3), object(14), timedelta64[ns](4)
# memory usage: 3.4+ KB
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 4             4      L NORRIS          NOR          norris          McLaren
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 63           63     G RUSSELL          RUS         russell         Mercedes
#
#    TeamColor    TeamId FirstName    LastName         FullName  ...  \
# 1     3671C6  red_bull       Max  Verstappen   Max Verstappen  ...
# 4     FF8000   mclaren     Lando      Norris     Lando Norris  ...
# 81    FF8000   mclaren     Oscar     Piastri    Oscar Piastri  ...
# 16    E80020   ferrari   Charles     Leclerc  Charles Leclerc  ...
# 63    27F4D2  mercedes    George     Russell   George Russell  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  \
# 1                   1.0                              NaN
# 4                   2.0                              NaN
# 81                  3.0                              NaN
# 16                  4.0                              NaN
# 63                  5.0                              NaN
#
#                        Q1                     Q2                     Q3 Time  \
# 1  0 days 00:01:27.943000 0 days 00:01:27.502000 0 days 00:01:26.983000  NaT
# 4  0 days 00:01:27.845000 0 days 00:01:27.146000 0 days 00:01:26.995000  NaT
# 81 0 days 00:01:27.687000 0 days 00:01:27.507000 0 days 00:01:27.027000  NaT
# 16 0 days 00:01:27.920000 0 days 00:01:27.555000 0 days 00:01:27.299000  NaT
# 63 0 days 00:01:27.843000 0 days 00:01:27.400000 0 days 00:01:27.318000  NaT
#
#    Status Points
# 1            NaN
# 4            NaN
# 81           NaN
# 16           NaN
# 63           NaN
#
# [5 rows x 21 columns]

# %%
session_2024.laps.info()
session_2024.laps.head(5)
# Out:
# <class 'fastf1.core.Laps'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                907 non-null    timedelta64[ns]
#  1   Driver              907 non-null    object
#  2   DriverNumber        907 non-null    object
#  3   LapTime             876 non-null    timedelta64[ns]
#  4   LapNumber           907 non-null    float64
#  5   Stint               907 non-null    float64
#  6   PitOutTime          54 non-null     timedelta64[ns]
#  7   PitInTime           55 non-null     timedelta64[ns]
#  8   Sector1Time         862 non-null    timedelta64[ns]
#  9   Sector2Time         904 non-null    timedelta64[ns]
#  10  Sector3Time         904 non-null    timedelta64[ns]
#  11  Sector1SessionTime  861 non-null    timedelta64[ns]
#  12  Sector2SessionTime  904 non-null    timedelta64[ns]
#  13  Sector3SessionTime  904 non-null    timedelta64[ns]
#  14  SpeedI1             683 non-null    float64
#  15  SpeedI2             904 non-null    float64
#  16  SpeedFL             849 non-null    float64
#  17  SpeedST             904 non-null    float64
#  18  IsPersonalBest      907 non-null    bool
#  19  Compound            907 non-null    object
#  20  TyreLife            907 non-null    float64
#  21  FreshTyre           907 non-null    bool
#  22  Team                907 non-null    object
#  23  LapStartTime        907 non-null    timedelta64[ns]
#  24  LapStartDate        907 non-null    datetime64[ns]
#  25  TrackStatus         907 non-null    object
#  26  Position            905 non-null    float64
#  27  Deleted             907 non-null    bool
#  28  DeletedReason       907 non-null    object
#  29  FastF1Generated     907 non-null    bool
#  30  IsAccurate          907 non-null    bool
# dtypes: bool(5), datetime64[ns](1), float64(8), object(6), timedelta64[ns](11)
# memory usage: 188.8+ KB
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 01:04:51.506000    VER            1 0 days 00:02:10.735000
# 1 0 days 01:33:22.630000    VER            1                    NaT
# 2 0 days 01:36:15.449000    VER            1                    NaT
# 3 0 days 01:37:51.921000    VER            1 0 days 00:01:36.472000
# 4 0 days 01:39:28.358000    VER            1 0 days 00:01:36.437000
#
#    LapNumber  Stint             PitOutTime              PitInTime  \
# 0        1.0    1.0                    NaT 0 days 01:04:49.856000
# 1        2.0    2.0 0 days 01:31:05.329000                    NaT
# 2        3.0    2.0                    NaT                    NaT
# 3        4.0    2.0                    NaT                    NaT
# 4        5.0    2.0                    NaT                    NaT
#
#              Sector1Time            Sector2Time  ... FreshTyre  \
# 0                    NaT 0 days 00:01:04.045000  ...      True
# 1                    NaT 0 days 00:00:56.617000  ...     False
# 2                    NaT 0 days 00:00:42.768000  ...     False
# 3 0 days 00:00:34.772000 0 days 00:00:43.042000  ...     False
# 4 0 days 00:00:34.690000 0 days 00:00:43.035000  ...     False
#
#               Team           LapStartTime            LapStartDate  \
# 0  Red Bull Racing 0 days 01:02:40.422000 2024-04-07 05:03:42.056
# 1  Red Bull Racing 0 days 01:30:58.774000 2024-04-07 05:32:00.408
# 2  Red Bull Racing 0 days 01:33:22.630000 2024-04-07 05:34:24.264
# 3  Red Bull Racing 0 days 01:36:15.449000 2024-04-07 05:37:17.083
# 4  Red Bull Racing 0 days 01:37:51.921000 2024-04-07 05:38:53.555
#
#    TrackStatus  Position  Deleted  DeletedReason  FastF1Generated IsAccurate
# 0          125       1.0    False                           False      False
# 1            1       1.0    False                           False      False
# 2            1       1.0    False                           False      False
# 3            1       1.0    False                           False       True
# 4            1       1.0    False                           False       True
#
# [5 rows x 31 columns]

# %%
session_2024.results.info()
session_2024.results.head()
# Out:
# <class 'fastf1.core.SessionResults'>
# Index: 20 entries, 1 to 23
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        20 non-null     object
#  1   BroadcastName       20 non-null     object
#  2   Abbreviation        20 non-null     object
#  3   DriverId            20 non-null     object
#  4   TeamName            20 non-null     object
#  5   TeamColor           20 non-null     object
#  6   TeamId              20 non-null     object
#  7   FirstName           20 non-null     object
#  8   LastName            20 non-null     object
#  9   FullName            20 non-null     object
#  10  HeadshotUrl         20 non-null     object
#  11  CountryCode         20 non-null     object
#  12  Position            20 non-null     float64
#  13  ClassifiedPosition  20 non-null     object
#  14  GridPosition        20 non-null     float64
#  15  Q1                  0 non-null      timedelta64[ns]
#  16  Q2                  0 non-null      timedelta64[ns]
#  17  Q3                  0 non-null      timedelta64[ns]
#  18  Time                17 non-null     timedelta64[ns]
#  19  Status              20 non-null     object
#  20  Points              20 non-null     float64
# dtypes: float64(3), object(14), timedelta64[ns](4)
# memory usage: 3.4+ KB
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 11           11       S PEREZ          PER           perez  Red Bull Racing
# 55           55       C SAINZ          SAI           sainz          Ferrari
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 4             4      L NORRIS          NOR          norris          McLaren
#
#    TeamColor    TeamId FirstName    LastName         FullName  ...  \
# 1     3671C6  red_bull       Max  Verstappen   Max Verstappen  ...
# 11    3671C6  red_bull    Sergio       Perez     Sergio Perez  ...
# 55    E80020   ferrari    Carlos       Sainz     Carlos Sainz  ...
# 16    E80020   ferrari   Charles     Leclerc  Charles Leclerc  ...
# 4     FF8000   mclaren     Lando      Norris     Lando Norris  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  Q1  Q2  Q3  \
# 1          NED      1.0                   1          1.0 NaT NaT NaT
# 11         MEX      2.0                   2          2.0 NaT NaT NaT
# 55         ESP      3.0                   3          4.0 NaT NaT NaT
# 16         MON      4.0                   4          8.0 NaT NaT NaT
# 4          GBR      5.0                   5          3.0 NaT NaT NaT
#
#                      Time    Status Points
# 1  0 days 01:54:23.566000  Finished   26.0
# 11 0 days 00:00:12.535000  Finished   18.0
# 55 0 days 00:00:20.866000  Finished   15.0
# 16 0 days 00:00:26.522000  Finished   12.0
# 4  0 days 00:00:29.700000  Finished   10.0
#
# [5 rows x 21 columns]

# %%
session_2024.weather_data.info()
session_2024.weather_data.describe()
# session_2024.weather_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Time           181 non-null    timedelta64[ns]
#  1   AirTemp        181 non-null    float64
#  2   Humidity       181 non-null    float64
#  3   Pressure       181 non-null    float64
#  4   Rainfall       181 non-null    bool
#  5   TrackTemp      181 non-null    float64
#  6   WindDirection  181 non-null    int64
#  7   WindSpeed      181 non-null    float64
# dtypes: bool(1), float64(5), int64(1), timedelta64[ns](1)
# memory usage: 10.2 KB
#                             Time     AirTemp    Humidity     Pressure  \
# count                        181  181.000000  181.000000   181.000000
# mean   0 days 01:30:40.840668508   21.691160   43.430939  1012.372376
# std    0 days 00:52:23.811553995    0.895066    5.761166     0.263121
# min       0 days 00:00:40.658000   19.500000   32.000000  1012.000000
# 25%       0 days 00:45:40.687000   21.200000   39.000000  1012.100000
# 50%       0 days 01:30:40.842000   22.100000   42.000000  1012.300000
# 75%       0 days 02:15:40.994000   22.400000   47.000000  1012.500000
# max       0 days 03:00:41.150000   22.700000   57.000000  1012.900000
#
#         TrackTemp  WindDirection   WindSpeed
# count  181.000000     181.000000  181.000000
# mean    37.501105     185.668508    2.240884
# std      2.799464      16.996096    0.665488
# min     31.300000     135.000000    0.900000
# 25%     35.400000     174.000000    1.800000
# 50%     39.000000     190.000000    2.200000
# 75%     39.700000     197.000000    2.600000
# max     40.500000     226.000000    4.200000

# %%
session_2024.laps['LapTime'].describe()
average_laptimes = session_2024.laps.groupby('Driver')['LapTime'].mean().reset_index()

# Sort the drivers from fastest (lowest avg lap time) to slowest
average_laptimes = average_laptimes.sort_values(by='LapTime', ascending=True)

print(average_laptimes)
# Out:
#    Driver                   LapTime
# 18    VER 0 days 00:01:37.637509803
# 10    PER 0 days 00:01:37.903705882
# 14    SAI 0 days 00:01:38.135137254
# 8     NOR 0 days 00:01:38.261392156
# 6     LEC 0 days 00:01:38.537588235
# 1     ALO 0 days 00:01:38.639313725
# 11    PIA 0 days 00:01:38.760941176
# 4     HAM 0 days 00:01:38.922862745
# 13    RUS 0 days 00:01:38.978901960
# 5     HUL    0 days 00:01:40.182440
# 17    TSU    0 days 00:01:40.239700
# 16    STR 0 days 00:01:41.298843137
# 2     BOT 0 days 00:01:41.448647058
# 7     MAG 0 days 00:01:41.488705882
# 9     OCO 0 days 00:01:41.825666666
# 3     GAS 0 days 00:01:42.096196078
# 15    SAR 0 days 00:01:42.584352941
# 19    ZHO 0 days 00:01:55.406272727
# 0     ALB                       NaT
# 12    RIC                       NaT

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error

# %%
quali24 = quali_2024.results[['DriverNumber', 'TeamName', 'Q1', 'Q2', 'Q3', 'Position', 'Abbreviation']].copy()
session24 = session_2024.results[['DriverNumber', 'Time']].copy()

# Join X and y on 'DriverNumber'
data = pd.merge(quali24, session24, on='DriverNumber', how='inner')

X_train = data[['TeamName', 'Q1', 'Q2', 'Q3', 'Position', 'Abbreviation']].copy()
y_train = data[['Time']].copy()
y_train.dropna(inplace=True)
y_train['Time'] = y_train['Time'].dt.total_seconds()
# Build X_predict with Abbreviation
X_predict = quali_2025.results[['TeamName', 'Q1', 'Q2', 'Q3', 'Position', 'Abbreviation']].copy()
# Save the Abbreviation for later display and remove it from features
driver_abbr = X_predict['Abbreviation'].copy()
X_predict = X_predict.drop(columns=['Abbreviation'])

# %%
winner_time = y_train['Time'].iloc[0]
y_train.iloc[1:, y_train.columns.get_loc('Time')] += winner_time

# %%
X_train = pd.get_dummies(X_train, columns=['TeamName'], prefix='Team')
X_predict = pd.get_dummies(X_predict, columns=['TeamName'], prefix='Team')
X_predict.rename(columns={'Team_Racing Bulls': 'Team_RB'}, inplace=True)

# %%
X_train['Q2'] = X_train['Q2'].fillna(X_train['Q1'])
X_train['Q3'] = X_train['Q3'].fillna(X_train['Q2'])
X_train = X_train[~X_train['Abbreviation'].isin(['ALB', 'ZHO', 'RIC'])]
X_train = X_train.drop(columns=['Abbreviation'])

# %%
# Align y_train with the remaining rows in X_train
y_train = y_train.loc[X_train.index]

# Reset the index for both X_train and y_train to ensure they match
X_train.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)

# %%
X_predict['Q2'] = X_predict['Q2'].fillna(X_predict['Q1'])
X_predict['Q3'] = X_predict['Q3'].fillna(X_predict['Q2'])

# %%
X_train['Q1'] = X_train['Q1'].dt.total_seconds()
X_train['Q2'] = X_train['Q2'].dt.total_seconds()
X_train['Q3'] = X_train['Q3'].dt.total_seconds()
X_predict['Q1'] = X_predict['Q1'].dt.total_seconds()
X_predict['Q2'] = X_predict['Q2'].dt.total_seconds()
X_predict['Q3'] = X_predict['Q3'].dt.total_seconds()

# %%
from sklearn.model_selection import cross_val_score, LeaveOneOut
from sklearn.ensemble import VotingRegressor
import xgboost as xgb

# # Feature engineering
# X_train['Q1_Q2_diff'] = X_train['Q1'] - X_train['Q2']
# X_train['Q2_Q3_diff'] = X_train['Q2'] - X_train['Q3']
# X_predict['Q1_Q2_diff'] = X_predict['Q1'] - X_predict['Q2']

# %%
# Initialize models
rf = RandomForestRegressor(n_estimators=100, random_state=42)
gb = GradientBoostingRegressor(n_estimators=100, random_state=42)
xgb_model = xgb.XGBRegressor(n_estimators=100, random_state=42)

# Create ensemble
ensemble = VotingRegressor([
    ('rf', rf),
    ('gb', gb),
    ('xgb', xgb_model)
])

# Use LeaveOneOut cross-validation due to small dataset
loo = LeaveOneOut()

# Calculate cross-validation scores for each model
models = {'Random Forest': rf, 'Gradient Boosting': gb, 'XGBoost': xgb_model, 'Ensemble': ensemble}
cv_results = {}

for name, model in models.items():
    scores = cross_val_score(model, X_train, y_train['Time'], 
                            scoring='neg_mean_absolute_error',
                            cv=loo)
    mae = -scores.mean()
    cv_results[name] = mae
    print(f'{name} CV MAE: {mae:.2f} seconds')
# Out:
# Random Forest CV MAE: 18.97 seconds
# Gradient Boosting CV MAE: 18.70 seconds
# Gradient Boosting CV MAE: 18.70 seconds
# XGBoost CV MAE: 17.73 seconds
# XGBoost CV MAE: 17.73 seconds
# Ensemble CV MAE: 17.64 seconds
# Ensemble CV MAE: 17.64 seconds

# %%
def seconds_to_time(seconds):
    h = int(seconds // 3600)
    m = int((seconds % 3600) // 60)
    s = seconds % 60
    return f"{h:02d}:{m:02d}:{s:06.3f}"

# %%
# Train and predict with each model
predictions = {}
for name, model in models.items():
    # Fit the model
    model.fit(X_train, y_train['Time'])
    
    # Make predictions
    pred = model.predict(X_predict)
    predictions[name] = pred
    
    # Create results DataFrame
    results = pd.DataFrame({
        'Abbreviation': driver_abbr,
        'Predicted_Race_Time_sec': pred,
        'Predicted_Race_Time': [seconds_to_time(s) for s in pred]
    })
    
    # Sort and display results
    results_sorted = results.sort_values('Predicted_Race_Time_sec')
    print(f"\n{name} Predictions:")
    print(results_sorted[['Abbreviation', 'Predicted_Race_Time']])
    print(f"MAE from cross-validation: {cv_results[name]:.2f} seconds")
# Out:
# Random Forest Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:34.984
# 22          TSU        01:54:41.618
# 30          LAW        01:54:42.848
# 6           HAD        01:54:44.203
# 87          BEA        01:54:44.394
# 16          LEC        01:54:44.955
# 4           NOR        01:54:47.004
# 44          HAM        01:54:47.728
# 27          HUL        01:54:48.057
# 81          PIA        01:54:48.635
# 14          ALO        01:54:49.489
# 5           BOR        01:54:49.664
# 31          OCO        01:54:49.896
# 55          SAI        01:54:50.353
# 23          ALB        01:54:51.156
# 10          GAS        01:54:53.475
# 63          RUS        01:54:54.019
# 12          ANT        01:54:54.522
# 18          STR        01:54:58.721
# 7           DOO        01:55:04.968
# MAE from cross-validation: 18.97 seconds
#
# Gradient Boosting Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:23.728
# 16          LEC        01:54:35.684
# 4           NOR        01:54:35.777
# 81          PIA        01:54:37.019
# 30          LAW        01:54:38.916
# 6           HAD        01:54:41.182
# 22          TSU        01:54:41.881
# 87          BEA        01:54:43.982
# 14          ALO        01:54:47.035
# 44          HAM        01:54:48.699
# 27          HUL        01:54:50.765
# 5           BOR        01:54:50.926
# 12          ANT        01:54:54.257
# 63          RUS        01:54:54.257
# 31          OCO        01:54:56.179
# 55          SAI        01:55:00.097
# 10          GAS        01:55:01.188
# 23          ALB        01:55:02.385
# 18          STR        01:55:04.399
# 7           DOO        01:55:26.822
# MAE from cross-validation: 18.70 seconds
#
# XGBoost Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:23.567
# 22          TSU        01:54:23.567
# 30          LAW        01:54:23.567
# 55          SAI        01:54:23.567
# 23          ALB        01:54:23.567
# 6           HAD        01:54:23.567
# 87          BEA        01:54:23.567
# 27          HUL        01:54:26.090
# 5           BOR        01:54:26.090
# 31          OCO        01:54:26.279
# 44          HAM        01:54:30.666
# 16          LEC        01:54:30.666
# 14          ALO        01:54:41.192
# 10          GAS        01:54:45.327
# 7           DOO        01:54:45.328
# 81          PIA        01:54:46.091
# 4           NOR        01:54:46.091
# 63          RUS        01:54:47.975
# 12          ANT        01:54:47.975
# 18          STR        01:55:00.657
# MAE from cross-validation: 17.73 seconds
#
# Ensemble Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:27.427
# 30          LAW        01:54:35.110
# 22          TSU        01:54:35.689
# 6           HAD        01:54:36.317
# 16          LEC        01:54:37.102
# 87          BEA        01:54:37.315
# 27          HUL        01:54:41.637
# 5           BOR        01:54:42.226
# 44          HAM        01:54:42.364
# 4           NOR        01:54:42.957
# 81          PIA        01:54:43.915
# 31          OCO        01:54:44.118
# 55          SAI        01:54:44.672
# 23          ALB        01:54:45.703
# 14          ALO        01:54:45.906
# 63          RUS        01:54:52.084
# 12          ANT        01:54:52.251
# 10          GAS        01:54:53.330
# 18          STR        01:55:01.259
# 7           DOO        01:55:05.706
# MAE from cross-validation: 17.64 seconds
#
# Ensemble Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:27.427
# 30          LAW        01:54:35.110
# 22          TSU        01:54:35.689
# 6           HAD        01:54:36.317
# 16          LEC        01:54:37.102
# 87          BEA        01:54:37.315
# 27          HUL        01:54:41.637
# 5           BOR        01:54:42.226
# 44          HAM        01:54:42.364
# 4           NOR        01:54:42.957
# 81          PIA        01:54:43.915
# 31          OCO        01:54:44.118
# 55          SAI        01:54:44.672
# 23          ALB        01:54:45.703
# 14          ALO        01:54:45.906
# 63          RUS        01:54:52.084
# 12          ANT        01:54:52.251
# 10          GAS        01:54:53.330
# 18          STR        01:55:01.259
# 7           DOO        01:55:05.706
# MAE from cross-validation: 17.64 seconds

# %%
# Feature importance analysis for each model that supports it
for name, model in models.items():
    if hasattr(model, 'feature_importances_'):
        print(f"\n{name} Feature Importances:")
        importances = pd.DataFrame({
            'feature': X_train.columns,
            'importance': model.feature_importances_
        })
        print(importances.sort_values('importance', ascending=False).head(10))
# Out:
# Random Forest Feature Importances:
#                  feature  importance
# 1                     Q2    0.170184
# 0                     Q1    0.146002
# 3               Position    0.139181
# 2                     Q3    0.112999
# 4            Team_Alpine    0.092772
# 10         Team_Mercedes    0.065200
# 7      Team_Haas F1 Team    0.051273
# 11               Team_RB    0.050892
# 12  Team_Red Bull Racing    0.041927
# 9           Team_McLaren    0.038930
#
# Gradient Boosting Feature Importances:
#                  feature  importance
# 3               Position    0.230432
# 2                     Q3    0.177967
# 1                     Q2    0.144863
# 4            Team_Alpine    0.128792
# 13         Team_Williams    0.091620
# 10         Team_Mercedes    0.056744
# 11               Team_RB    0.050831
# 7      Team_Haas F1 Team    0.045383
# 12  Team_Red Bull Racing    0.044876
# 0                     Q1    0.020304
#
# XGBoost Feature Importances:
#               feature  importance
# 10      Team_Mercedes    0.485783
# 9        Team_McLaren    0.136741
# 6        Team_Ferrari    0.133735
# 4         Team_Alpine    0.082969
# 7   Team_Haas F1 Team    0.065942
# 5   Team_Aston Martin    0.035906
# 0                  Q1    0.023453
# 8    Team_Kick Sauber    0.012375
# 2                  Q3    0.012077
# 1                  Q2    0.009002

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Standardize numerical features in X_train
numerical_features = ['Q1', 'Q2', 'Q3', 'Position']
X_train[numerical_features] = scaler.fit_transform(X_train[numerical_features])

# Standardize numerical features in X_predict using the same scaler
X_predict[numerical_features] = scaler.transform(X_predict[numerical_features])

# Standardize the target variable
y_scaler = StandardScaler()
y_train_scaled = y_scaler.fit_transform(y_train)

print('Data standardization completed.')
# Out:
# Data standardization completed.

# %%
# Modify the model training and prediction code to handle scaled data
models = {'Random Forest': rf, 'Gradient Boosting': gb, 'XGBoost': xgb_model, 'Ensemble': ensemble}
predictions = {}

for name, model in models.items():
    # Fit the model with scaled data
    model.fit(X_train, y_train_scaled.ravel())
    
    # Make predictions and inverse transform to original scale
    pred_scaled = model.predict(X_predict)
    pred = y_scaler.inverse_transform(pred_scaled.reshape(-1, 1)).ravel()
    predictions[name] = pred
    
    # Create results DataFrame
    results = pd.DataFrame({
        'Abbreviation': driver_abbr,
        'Predicted_Race_Time_sec': pred,
        'Predicted_Race_Time': [seconds_to_time(s) for s in pred]
    })
    
    # Sort and display results
    results_sorted = results.sort_values('Predicted_Race_Time_sec')
    print(f"\n{name} Predictions:")
    print(results_sorted[['Abbreviation', 'Predicted_Race_Time']])
    print(f"MAE from cross-validation: {cv_results[name]:.2f} seconds")
# Out:
# Random Forest Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:34.856
# 22          TSU        01:54:39.740
# 30          LAW        01:54:41.853
# 87          BEA        01:54:42.083
# 6           HAD        01:54:42.951
# 16          LEC        01:54:43.055
# 44          HAM        01:54:45.125
# 4           NOR        01:54:46.206
# 27          HUL        01:54:46.487
# 81          PIA        01:54:46.946
# 14          ALO        01:54:46.974
# 5           BOR        01:54:48.031
# 31          OCO        01:54:48.853
# 55          SAI        01:54:49.686
# 23          ALB        01:54:50.421
# 63          RUS        01:54:51.212
# 10          GAS        01:54:51.874
# 12          ANT        01:54:51.898
# 18          STR        01:54:57.747
# 7           DOO        01:55:02.876
# MAE from cross-validation: 18.97 seconds
#
# Gradient Boosting Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:23.728
# 16          LEC        01:54:35.684
# 4           NOR        01:54:35.777
# 81          PIA        01:54:37.019
# 30          LAW        01:54:38.916
# 6           HAD        01:54:41.182
# 22          TSU        01:54:41.881
# 87          BEA        01:54:43.982
# 14          ALO        01:54:47.035
# 44          HAM        01:54:48.699
# 27          HUL        01:54:50.765
# 5           BOR        01:54:50.926
# 18          STR        01:54:54.180
# 12          ANT        01:54:54.257
# 63          RUS        01:54:54.257
# 31          OCO        01:54:56.179
# 55          SAI        01:54:59.107
# 10          GAS        01:55:01.188
# 23          ALB        01:55:01.395
# 7           DOO        01:55:23.783
# MAE from cross-validation: 18.70 seconds
#
# XGBoost Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:23.589
# 22          TSU        01:54:23.589
# 30          LAW        01:54:23.589
# 55          SAI        01:54:23.589
# 23          ALB        01:54:23.589
# 6           HAD        01:54:23.589
# 87          BEA        01:54:23.589
# 27          HUL        01:54:26.111
# 5           BOR        01:54:26.111
# 31          OCO        01:54:26.300
# 44          HAM        01:54:30.687
# 16          LEC        01:54:30.687
# 14          ALO        01:54:41.213
# 7           DOO        01:54:45.349
# 10          GAS        01:54:45.349
# 81          PIA        01:54:46.376
# 4           NOR        01:54:46.376
# 63          RUS        01:54:48.001
# 12          ANT        01:54:48.001
# 18          STR        01:55:00.459
# MAE from cross-validation: 17.73 seconds
#
# Gradient Boosting Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:23.728
# 16          LEC        01:54:35.684
# 4           NOR        01:54:35.777
# 81          PIA        01:54:37.019
# 30          LAW        01:54:38.916
# 6           HAD        01:54:41.182
# 22          TSU        01:54:41.881
# 87          BEA        01:54:43.982
# 14          ALO        01:54:47.035
# 44          HAM        01:54:48.699
# 27          HUL        01:54:50.765
# 5           BOR        01:54:50.926
# 18          STR        01:54:54.180
# 12          ANT        01:54:54.257
# 63          RUS        01:54:54.257
# 31          OCO        01:54:56.179
# 55          SAI        01:54:59.107
# 10          GAS        01:55:01.188
# 23          ALB        01:55:01.395
# 7           DOO        01:55:23.783
# MAE from cross-validation: 18.70 seconds
#
# XGBoost Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:23.589
# 22          TSU        01:54:23.589
# 30          LAW        01:54:23.589
# 55          SAI        01:54:23.589
# 23          ALB        01:54:23.589
# 6           HAD        01:54:23.589
# 87          BEA        01:54:23.589
# 27          HUL        01:54:26.111
# 5           BOR        01:54:26.111
# 31          OCO        01:54:26.300
# 44          HAM        01:54:30.687
# 16          LEC        01:54:30.687
# 14          ALO        01:54:41.213
# 7           DOO        01:54:45.349
# 10          GAS        01:54:45.349
# 81          PIA        01:54:46.376
# 4           NOR        01:54:46.376
# 63          RUS        01:54:48.001
# 12          ANT        01:54:48.001
# 18          STR        01:55:00.459
# MAE from cross-validation: 17.73 seconds
#
# Ensemble Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:27.391
# 30          LAW        01:54:34.786
# 22          TSU        01:54:35.070
# 6           HAD        01:54:35.907
# 16          LEC        01:54:36.475
# 87          BEA        01:54:36.552
# 27          HUL        01:54:41.121
# 44          HAM        01:54:41.504
# 5           BOR        01:54:41.689
# 4           NOR        01:54:42.787
# 81          PIA        01:54:43.447
# 31          OCO        01:54:43.777
# 55          SAI        01:54:44.128
# 14          ALO        01:54:45.074
# 23          ALB        01:54:45.135
# 63          RUS        01:54:51.157
# 12          ANT        01:54:51.386
# 10          GAS        01:54:52.804
# 18          STR        01:54:57.462
# 7           DOO        01:55:04.003
# MAE from cross-validation: 17.64 seconds
#
# Ensemble Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        01:54:27.391
# 30          LAW        01:54:34.786
# 22          TSU        01:54:35.070
# 6           HAD        01:54:35.907
# 16          LEC        01:54:36.475
# 87          BEA        01:54:36.552
# 27          HUL        01:54:41.121
# 44          HAM        01:54:41.504
# 5           BOR        01:54:41.689
# 4           NOR        01:54:42.787
# 81          PIA        01:54:43.447
# 31          OCO        01:54:43.777
# 55          SAI        01:54:44.128
# 14          ALO        01:54:45.074
# 23          ALB        01:54:45.135
# 63          RUS        01:54:51.157
# 12          ANT        01:54:51.386
# 10          GAS        01:54:52.804
# 18          STR        01:54:57.462
# 7           DOO        01:55:04.003
# MAE from cross-validation: 17.64 seconds

# %%
# Get the winner (driver with lowest predicted race time)
winner_abb = results_sorted['Abbreviation'].iloc[0]

# Get the full driver name from qualifying data
winner_data = quali_2025.results[quali_2025.results['Abbreviation'] == winner_abb]
winner_name = winner_data['FullName'].iloc[0]

print(f"And the winner of the 2025 Japanese Grand Prix is {winner_name}!")
# Out:
# And the winner of the 2025 Japanese Grand Prix is Max Verstappen!

# %%
from IPython.display import Markdown

# Get the winner (driver with lowest predicted race time)
winner_abb = results_sorted['Abbreviation'].iloc[0]

# Get the full driver name from qualifying data
winner_data = quali_2025.results[quali_2025.results['Abbreviation'] == winner_abb]
winner_name = winner_data['FullName'].iloc[0]

markdown_text = f"""## 🏆 Race Winner Prediction


### And the winner of the 2025 Japanese Grand Prix is:
# 🏎️ {winner_name}

With a predicted race time of: **{results_sorted['Predicted_Race_Time'].iloc[0]}** and a MAE of **{cv_results['Ensemble']:.2f} seconds**."""

display(Markdown(markdown_text))
# Out:
# ## 🏆 Race Winner Prediction
#
#
# ### And the winner of the 2025 Japanese Grand Prix is:
# # 🏎️ Max Verstappen
#
# With a predicted race time of: **01:54:27.391** and a MAE of **17.64 seconds**.
