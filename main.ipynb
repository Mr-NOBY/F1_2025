# %%
import fastf1
cache_location = 'C:\\Users\\Ahmed Essam\\development\\AI\\F1\\f1cache'
fastf1.Cache.enable_cache(cache_location)
grand_prix = 'Jeddah'
current_year = 2025
previous_year = current_year - 1

# %%
# Load FastF1 2024 GP race session
session_2024 = fastf1.get_session(previous_year, grand_prix, "R")
session_2024.load()
# Out:
# core           INFO 	Loading data for Saudi Arabian Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '16', '81', '14', '63', '38', '4', '44', '27', '23', '20', '31', '2', '22', '3', '77', '24', '18', '10']

# %%
session_2024.results.info()
session_2024.results.head(5)
# Out:
# <class 'fastf1.core.SessionResults'>
# Index: 20 entries, 1 to 10
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        20 non-null     object
#  1   BroadcastName       20 non-null     object
#  2   Abbreviation        20 non-null     object
#  3   DriverId            20 non-null     object
#  4   TeamName            20 non-null     object
#  5   TeamColor           20 non-null     object
#  6   TeamId              20 non-null     object
#  7   FirstName           20 non-null     object
#  8   LastName            20 non-null     object
#  9   FullName            20 non-null     object
#  10  HeadshotUrl         20 non-null     object
#  11  CountryCode         20 non-null     object
#  12  Position            20 non-null     float64
#  13  ClassifiedPosition  20 non-null     object
#  14  GridPosition        20 non-null     float64
#  15  Q1                  0 non-null      timedelta64[ns]
#  16  Q2                  0 non-null      timedelta64[ns]
#  17  Q3                  0 non-null      timedelta64[ns]
#  18  Time                18 non-null     timedelta64[ns]
#  19  Status              20 non-null     object
#  20  Points              20 non-null     float64
# dtypes: float64(3), object(14), timedelta64[ns](4)
# memory usage: 3.4+ KB
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 11           11       S PEREZ          PER           perez  Red Bull Racing
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 14           14      F ALONSO          ALO          alonso     Aston Martin
#
#    TeamColor        TeamId FirstName    LastName         FullName  ...  \
# 1     3671c6      red_bull       Max  Verstappen   Max Verstappen  ...
# 11    3671c6      red_bull    Sergio       Perez     Sergio Perez  ...
# 16    e8002d       ferrari   Charles     Leclerc  Charles Leclerc  ...
# 81    ff8000       mclaren     Oscar     Piastri    Oscar Piastri  ...
# 14    229971  aston_martin  Fernando      Alonso  Fernando Alonso  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  Q1  Q2  Q3  \
# 1          NED      1.0                   1          1.0 NaT NaT NaT
# 11         MEX      2.0                   2          3.0 NaT NaT NaT
# 16         MON      3.0                   3          2.0 NaT NaT NaT
# 81         AUS      4.0                   4          5.0 NaT NaT NaT
# 14         ESP      5.0                   5          4.0 NaT NaT NaT
#
#                      Time    Status Points
# 1  0 days 01:20:43.273000  Finished   25.0
# 11 0 days 00:00:13.643000  Finished   18.0
# 16 0 days 00:00:18.639000  Finished   16.0
# 81 0 days 00:00:32.007000  Finished   12.0
# 14 0 days 00:00:35.759000  Finished   10.0
#
# [5 rows x 21 columns]

# %%
quali_2025 = fastf1.get_session(current_year, grand_prix, "Q")
quali_2025.load()
quali_2024 = fastf1.get_session(previous_year, grand_prix, "Q")
quali_2024.load()
# Out:
# core           INFO 	Loading data for Saudi Arabian Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '81', '63', '16', '12', '55', '44', '22', '10', '4', '23', '30', '14', '6', '87', '18', '7', '27', '31', '5']
# core           INFO 	Loading data for Saudi Arabian Grand Prix - Qualifying [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '11', '14', '81', '4', '63', '44', '22', '18', '38', '23', '20', '3', '27', '77', '31', '10', '2', '24']

# %%
quali_2025.results.info()
quali_2025.results.head(5)
# Out:
# <class 'fastf1.core.SessionResults'>
# Index: 20 entries, 1 to 5
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        20 non-null     object
#  1   BroadcastName       20 non-null     object
#  2   Abbreviation        20 non-null     object
#  3   DriverId            20 non-null     object
#  4   TeamName            20 non-null     object
#  5   TeamColor           20 non-null     object
#  6   TeamId              20 non-null     object
#  7   FirstName           20 non-null     object
#  8   LastName            20 non-null     object
#  9   FullName            20 non-null     object
#  10  HeadshotUrl         20 non-null     object
#  11  CountryCode         20 non-null     object
#  12  Position            20 non-null     float64
#  13  ClassifiedPosition  20 non-null     object
#  14  GridPosition        0 non-null      float64
#  15  Q1                  20 non-null     timedelta64[ns]
#  16  Q2                  15 non-null     timedelta64[ns]
#  17  Q3                  9 non-null      timedelta64[ns]
#  18  Time                0 non-null      timedelta64[ns]
#  19  Status              20 non-null     object
#  20  Points              0 non-null      float64
# dtypes: float64(3), object(14), timedelta64[ns](4)
# memory usage: 3.4+ KB
#    DriverNumber BroadcastName Abbreviation DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER           Red Bull Racing
# 81           81     O PIASTRI          PIA                   McLaren
# 63           63     G RUSSELL          RUS                  Mercedes
# 16           16     C LECLERC          LEC                   Ferrari
# 12           12   K ANTONELLI          ANT                  Mercedes
#
#    TeamColor TeamId FirstName    LastName         FullName  ... CountryCode  \
# 1     3671C6              Max  Verstappen   Max Verstappen  ...
# 81    FF8000            Oscar     Piastri    Oscar Piastri  ...
# 63    27F4D2           George     Russell   George Russell  ...
# 16    E80020          Charles     Leclerc  Charles Leclerc  ...
# 12    27F4D2             Kimi   Antonelli   Kimi Antonelli  ...
#
#    Position  ClassifiedPosition GridPosition                     Q1  \
# 1       1.0                              NaN 0 days 00:01:27.778000
# 81      2.0                              NaN 0 days 00:01:27.901000
# 63      3.0                              NaN 0 days 00:01:28.282000
# 16      4.0                              NaN 0 days 00:01:28.552000
# 12      5.0                              NaN 0 days 00:01:28.128000
#
#                        Q2                     Q3 Time Status Points
# 1  0 days 00:01:27.529000 0 days 00:01:27.294000  NaT           NaN
# 81 0 days 00:01:27.545000 0 days 00:01:27.304000  NaT           NaN
# 63 0 days 00:01:27.599000 0 days 00:01:27.407000  NaT           NaN
# 16 0 days 00:01:27.866000 0 days 00:01:27.670000  NaT           NaN
# 12 0 days 00:01:27.798000 0 days 00:01:27.866000  NaT           NaN
#
# [5 rows x 21 columns]

# %%
session_2024.laps.info()
session_2024.laps.head(5)
# Out:
# <class 'fastf1.core.Laps'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                901 non-null    timedelta64[ns]
#  1   Driver              901 non-null    object
#  2   DriverNumber        901 non-null    object
#  3   LapTime             873 non-null    timedelta64[ns]
#  4   LapNumber           901 non-null    float64
#  5   Stint               901 non-null    float64
#  6   PitOutTime          19 non-null     timedelta64[ns]
#  7   PitInTime           20 non-null     timedelta64[ns]
#  8   Sector1Time         879 non-null    timedelta64[ns]
#  9   Sector2Time         900 non-null    timedelta64[ns]
#  10  Sector3Time         900 non-null    timedelta64[ns]
#  11  Sector1SessionTime  876 non-null    timedelta64[ns]
#  12  Sector2SessionTime  900 non-null    timedelta64[ns]
#  13  Sector3SessionTime  900 non-null    timedelta64[ns]
#  14  SpeedI1             664 non-null    float64
#  15  SpeedI2             900 non-null    float64
#  16  SpeedFL             880 non-null    float64
#  17  SpeedST             900 non-null    float64
#  18  IsPersonalBest      900 non-null    object
#  19  Compound            901 non-null    object
#  20  TyreLife            901 non-null    float64
#  21  FreshTyre           901 non-null    bool
#  22  Team                901 non-null    object
#  23  LapStartTime        901 non-null    timedelta64[ns]
#  24  LapStartDate        900 non-null    datetime64[ns]
#  25  TrackStatus         901 non-null    object
#  26  Position            900 non-null    float64
#  27  Deleted             901 non-null    bool
#  28  DeletedReason       900 non-null    object
#  29  FastF1Generated     901 non-null    bool
#  30  IsAccurate          901 non-null    bool
# dtypes: bool(4), datetime64[ns](1), float64(8), object(7), timedelta64[ns](11)
# memory usage: 193.7+ KB
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 01:01:19.630000    VER            1 0 days 00:01:35.505000
# 1 0 days 01:02:53.835000    VER            1 0 days 00:01:34.205000
# 2 0 days 01:04:27.878000    VER            1 0 days 00:01:34.043000
# 3 0 days 01:06:01.632000    VER            1 0 days 00:01:33.754000
# 4 0 days 01:07:35.587000    VER            1 0 days 00:01:33.955000
#
#    LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0        NaT       NaT                    NaT
# 1        2.0    1.0        NaT       NaT 0 days 00:00:34.720000
# 2        3.0    1.0        NaT       NaT 0 days 00:00:34.530000
# 3        4.0    1.0        NaT       NaT 0 days 00:00:34.416000
# 4        5.0    1.0        NaT       NaT 0 days 00:00:34.457000
#
#              Sector2Time  ... FreshTyre             Team  \
# 0 0 days 00:00:29.707000  ...      True  Red Bull Racing
# 1 0 days 00:00:29.628000  ...      True  Red Bull Racing
# 2 0 days 00:00:29.621000  ...      True  Red Bull Racing
# 3 0 days 00:00:29.541000  ...      True  Red Bull Racing
# 4 0 days 00:00:29.590000  ...      True  Red Bull Racing
#
#             LapStartTime            LapStartDate  TrackStatus  Position  \
# 0 0 days 00:59:43.836000 2024-03-09 17:03:59.056            1       1.0
# 1 0 days 01:01:19.630000 2024-03-09 17:05:34.850            1       1.0
# 2 0 days 01:02:53.835000 2024-03-09 17:07:09.055            1       1.0
# 3 0 days 01:04:27.878000 2024-03-09 17:08:43.098            1       1.0
# 4 0 days 01:06:01.632000 2024-03-09 17:10:16.852            1       1.0
#
#    Deleted  DeletedReason FastF1Generated IsAccurate
# 0    False                          False      False
# 1    False                          False       True
# 2    False                          False       True
# 3    False                          False       True
# 4    False                          False       True
#
# [5 rows x 31 columns]

# %%
session_2024.results.info()
session_2024.results.head()
# Out:
# <class 'fastf1.core.SessionResults'>
# Index: 20 entries, 1 to 10
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        20 non-null     object
#  1   BroadcastName       20 non-null     object
#  2   Abbreviation        20 non-null     object
#  3   DriverId            20 non-null     object
#  4   TeamName            20 non-null     object
#  5   TeamColor           20 non-null     object
#  6   TeamId              20 non-null     object
#  7   FirstName           20 non-null     object
#  8   LastName            20 non-null     object
#  9   FullName            20 non-null     object
#  10  HeadshotUrl         20 non-null     object
#  11  CountryCode         20 non-null     object
#  12  Position            20 non-null     float64
#  13  ClassifiedPosition  20 non-null     object
#  14  GridPosition        20 non-null     float64
#  15  Q1                  0 non-null      timedelta64[ns]
#  16  Q2                  0 non-null      timedelta64[ns]
#  17  Q3                  0 non-null      timedelta64[ns]
#  18  Time                18 non-null     timedelta64[ns]
#  19  Status              20 non-null     object
#  20  Points              20 non-null     float64
# dtypes: float64(3), object(14), timedelta64[ns](4)
# memory usage: 3.4+ KB
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 11           11       S PEREZ          PER           perez  Red Bull Racing
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 14           14      F ALONSO          ALO          alonso     Aston Martin
#
#    TeamColor        TeamId FirstName    LastName         FullName  ...  \
# 1     3671c6      red_bull       Max  Verstappen   Max Verstappen  ...
# 11    3671c6      red_bull    Sergio       Perez     Sergio Perez  ...
# 16    e8002d       ferrari   Charles     Leclerc  Charles Leclerc  ...
# 81    ff8000       mclaren     Oscar     Piastri    Oscar Piastri  ...
# 14    229971  aston_martin  Fernando      Alonso  Fernando Alonso  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  Q1  Q2  Q3  \
# 1          NED      1.0                   1          1.0 NaT NaT NaT
# 11         MEX      2.0                   2          3.0 NaT NaT NaT
# 16         MON      3.0                   3          2.0 NaT NaT NaT
# 81         AUS      4.0                   4          5.0 NaT NaT NaT
# 14         ESP      5.0                   5          4.0 NaT NaT NaT
#
#                      Time    Status Points
# 1  0 days 01:20:43.273000  Finished   25.0
# 11 0 days 00:00:13.643000  Finished   18.0
# 16 0 days 00:00:18.639000  Finished   16.0
# 81 0 days 00:00:32.007000  Finished   12.0
# 14 0 days 00:00:35.759000  Finished   10.0
#
# [5 rows x 21 columns]

# %%
session_2024.weather_data.info()
session_2024.weather_data.describe()
# session_2024.weather_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Time           146 non-null    timedelta64[ns]
#  1   AirTemp        146 non-null    float64
#  2   Humidity       146 non-null    float64
#  3   Pressure       146 non-null    float64
#  4   Rainfall       146 non-null    bool
#  5   TrackTemp      146 non-null    float64
#  6   WindDirection  146 non-null    int64
#  7   WindSpeed      146 non-null    float64
# dtypes: bool(1), float64(5), int64(1), timedelta64[ns](1)
# memory usage: 8.3 KB
#                             Time     AirTemp    Humidity     Pressure  \
# count                        146  146.000000  146.000000   146.000000
# mean   0 days 01:12:38.609691780   25.528082   62.335616  1012.682877
# std    0 days 00:42:17.620908200    0.133774    2.624230     0.344686
# min       0 days 00:00:08.340000   25.200000   57.000000  1012.000000
# 25%       0 days 00:36:23.390500   25.500000   61.000000  1012.400000
# 50%       0 days 01:12:38.632000   25.500000   62.000000  1012.700000
# 75%       0 days 01:48:53.829250   25.600000   64.000000  1013.000000
# max       0 days 02:25:08.869000   25.900000   67.000000  1013.200000
#
#         TrackTemp  WindDirection   WindSpeed
# count  146.000000     146.000000  146.000000
# mean    31.593151     129.143836    1.302740
# std      1.058213     147.965093    0.558439
# min     29.100000       0.000000    0.000000
# 25%     30.900000      11.250000    0.900000
# 50%     31.500000      30.500000    1.200000
# 75%     32.200000     320.750000    1.700000
# max     33.600000     359.000000    2.600000

# %%
session_2024.laps['LapTime'].describe()
average_laptimes = session_2024.laps.groupby('Driver')['LapTime'].mean().reset_index()

# Sort the drivers from fastest (lowest avg lap time) to slowest
average_laptimes = average_laptimes.sort_values(by='LapTime', ascending=True)

print(average_laptimes)
# Out:
#    Driver                   LapTime
# 18    VER 0 days 00:01:33.608229166
# 11    PER 0 days 00:01:33.867729166
# 7     LEC 0 days 00:01:34.101208333
# 12    PIA 0 days 00:01:34.468937500
# 1     ALO    0 days 00:01:34.557750
# 14    RUS 0 days 00:01:34.753187500
# 9     NOR 0 days 00:01:34.858020833
# 5     HAM 0 days 00:01:34.955041666
# 6     HUL    0 days 00:01:35.764625
# 2     BEA 0 days 00:01:36.048244897
# 8     MAG 0 days 00:01:36.918020408
# 0     ALB 0 days 00:01:36.972326530
# 16    STR    0 days 00:01:37.121600
# 17    TSU 0 days 00:01:37.275916666
# 13    RIC 0 days 00:01:37.297416666
# 10    OCO 0 days 00:01:37.310541666
# 15    SAR    0 days 00:01:37.349375
# 3     BOT 0 days 00:01:37.688666666
# 19    ZHO 0 days 00:01:38.048479166
# 4     GAS    0 days 00:02:01.453000

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error

# %%
quali24 = quali_2024.results[['DriverNumber', 'TeamName', 'Q1', 'Q2', 'Q3', 'Position', 'Abbreviation']].copy()
session24 = session_2024.results[['DriverNumber', 'Time', 'Status']].copy()

# Join X and y on 'DriverNumber'
data = pd.merge(quali24, session24, on='DriverNumber', how='inner')

max_laptime = average_laptimes['LapTime'].max()
data.loc[data['Status'] == 'Lapped', 'Time'] += max_laptime
print(data['Time'])
# Drop rows where 'Time' is NaT and get the corresponding 'Abbreviation'
missing_time_abbr = data[data['Time'].isna()]['Abbreviation']
print("Abbreviations with missing Time:", missing_time_abbr.tolist())
data = data.dropna(subset=['Time'])
X_train = data[['TeamName', 'Q1', 'Q2', 'Q3', 'Position', 'Abbreviation']].copy()
# X_train = data[[ 'Q1', 'Q2', 'Q3', 'Position', 'Abbreviation']].copy()

y_train = data[['Time']].copy()
y_train.dropna(inplace=True)
y_train['Time'] = y_train['Time'].dt.total_seconds()
# Build X_predict with Abbreviation
X_predict = quali_2025.results[['TeamName', 'Q1', 'Q2', 'Q3', 'Position', 'Abbreviation']].copy()
# X_predict = quali_2025.results[['Q1', 'Q2', 'Q3', 'Position', 'Abbreviation']].copy()

# Save the Abbreviation for later display and remove it from features
driver_abbr = X_predict['Abbreviation'].copy()
X_predict = X_predict.drop(columns=['Abbreviation'])
# Out:
# 0    0 days 01:20:43.273000
# 1    0 days 00:00:18.639000
# 2    0 days 00:00:13.643000
# 3    0 days 00:00:35.759000
# 4    0 days 00:00:32.007000
# 5    0 days 00:00:45.708000
# 6    0 days 00:00:39.936000
# 7    0 days 00:00:47.391000
# 8    0 days 00:02:11.986000
# 9                       NaT
# 10   0 days 00:00:42.679000
# 11   0 days 00:01:28.354000
# 12   0 days 00:01:45.737000
# 13   0 days 00:02:22.168000
# 14   0 days 00:01:16.996000
# 15   0 days 00:02:24.568000
# 16   0 days 00:02:05.454000
# 17                      NaT
# 18   0 days 00:02:08.238000
# 19   0 days 00:02:31.006000
# Name: Time, dtype: timedelta64[ns]
# Abbreviations with missing Time: ['STR', 'GAS']

# %%
# winner_time = y_train['Time'].iloc[0]
# y_train.iloc[1:, y_train.columns.get_loc('Time')] += winner_time
y_train.loc[0, 'Time'] = 0.0

# %%
print(X_train, y_train)
print("the train std of Q2 and Q3 is: ", X_train[['Q2', 'Q3']].std())
print("the predict std of Q2 and Q3 is: ", X_predict[['Q2', 'Q3']].std())
# Out:
#            TeamName                     Q1                     Q2  \
# 0   Red Bull Racing 0 days 00:01:28.171000 0 days 00:01:28.033000
# 1           Ferrari 0 days 00:01:28.318000 0 days 00:01:28.112000
# 2   Red Bull Racing 0 days 00:01:28.638000 0 days 00:01:28.467000
# 3      Aston Martin 0 days 00:01:28.706000 0 days 00:01:28.122000
# 4           McLaren 0 days 00:01:28.755000 0 days 00:01:28.343000
# 5           McLaren 0 days 00:01:28.805000 0 days 00:01:28.479000
# 6          Mercedes 0 days 00:01:28.749000 0 days 00:01:28.448000
# 7          Mercedes 0 days 00:01:28.994000 0 days 00:01:28.606000
# 8                RB 0 days 00:01:28.988000 0 days 00:01:28.564000
# 10          Ferrari 0 days 00:01:28.984000 0 days 00:01:28.642000
# 11         Williams 0 days 00:01:29.107000 0 days 00:01:28.980000
# 12     Haas F1 Team 0 days 00:01:29.069000 0 days 00:01:29.020000
# 13               RB 0 days 00:01:29.065000 0 days 00:01:29.025000
# 14     Haas F1 Team 0 days 00:01:29.055000                    NaT
# 15      Kick Sauber 0 days 00:01:29.179000                    NaT
# 16           Alpine 0 days 00:01:29.475000                    NaT
# 18         Williams 0 days 00:01:29.526000                    NaT
# 19      Kick Sauber                    NaT                    NaT
#
#                        Q3  Position Abbreviation
# 0  0 days 00:01:27.472000       1.0          VER
# 1  0 days 00:01:27.791000       2.0          LEC
# 2  0 days 00:01:27.807000       3.0          PER
# 3  0 days 00:01:27.846000       4.0          ALO
# 4  0 days 00:01:28.089000       5.0          PIA
# 5  0 days 00:01:28.132000       6.0          NOR
# 6  0 days 00:01:28.316000       7.0          RUS
# 7  0 days 00:01:28.460000       8.0          HAM
# 8  0 days 00:01:28.547000       9.0          TSU
# 10                    NaT      11.0          BEA
# 11                    NaT      12.0          ALB
# 12                    NaT      13.0          MAG
# 13                    NaT      14.0          RIC
# 14                    NaT      15.0          HUL
# 15                    NaT      16.0          BOT
# 16                    NaT      17.0          OCO
# 18                    NaT      19.0          SAR
# 19                    NaT      20.0          ZHO          Time
# 0     0.000
# 1    18.639
# 2    13.643
# 3    35.759
# 4    32.007
# 5    45.708
# 6    39.936
# 7    47.391
# 8   131.986
# 10   42.679
# 11   88.354
# 12  105.737
# 13  142.168
# 14   76.996
# 15  144.568
# 16  125.454
# 18  128.238
# 19  151.006
# the train std of Q2 and Q3 is:  Q2   0 days 00:00:00.334586350
# Q3   0 days 00:00:00.352832979
# dtype: timedelta64[ns]
# the predict std of Q2 and Q3 is:  Q2   0 days 00:00:00.343829941
# Q3   0 days 00:00:00.425328337
# dtype: timedelta64[ns]

# %%
X_train = pd.get_dummies(X_train, columns=['TeamName'], prefix='Team')
X_predict = pd.get_dummies(X_predict, columns=['TeamName'], prefix='Team')
X_predict.rename(columns={'Team_Racing Bulls': 'Team_RB'}, inplace=True)

# %%
X_train['Q1'] = X_train['Q1'].fillna(X_train['Q1'].max() + pd.Timedelta(seconds=5))
X_train['Q2'] = X_train['Q2'].fillna(X_train['Q1'] + pd.Timedelta(seconds=10))
X_train['Q3'] = X_train['Q3'].fillna(X_train['Q2'] + pd.Timedelta(seconds=10))
# X_train = X_train[~X_train['Abbreviation'].isin(['ALB', 'ZHO', 'RIC'])]
X_train = X_train.drop(columns=['Abbreviation'])

# %%
# Align y_train with the remaining rows in X_train
y_train = y_train.loc[X_train.index]

# Reset the index for both X_train and y_train to ensure they match
X_train.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)

# %%
X_predict['Q2'] = X_predict['Q2'].fillna(X_predict['Q1'] + pd.Timedelta(seconds=10))
X_predict['Q3'] = X_predict['Q3'].fillna(X_predict['Q2'] + pd.Timedelta(seconds=10))

# %%
X_train['Q1'] = X_train['Q1'].dt.total_seconds()
X_train['Q2'] = X_train['Q2'].dt.total_seconds()
X_train['Q3'] = X_train['Q3'].dt.total_seconds()
X_predict['Q1'] = X_predict['Q1'].dt.total_seconds()
X_predict['Q2'] = X_predict['Q2'].dt.total_seconds()
X_predict['Q3'] = X_predict['Q3'].dt.total_seconds()

# %%
print(pd.concat([X_train, y_train], axis=1))
# Out:
#         Q1       Q2       Q3  Position  Team_Alpine  Team_Aston Martin  \
# 0   88.171   88.033   87.472       1.0        False              False
# 1   88.318   88.112   87.791       2.0        False              False
# 2   88.638   88.467   87.807       3.0        False              False
# 3   88.706   88.122   87.846       4.0        False               True
# 4   88.755   88.343   88.089       5.0        False              False
# 5   88.805   88.479   88.132       6.0        False              False
# 6   88.749   88.448   88.316       7.0        False              False
# 7   88.994   88.606   88.460       8.0        False              False
# 8   88.988   88.564   88.547       9.0        False              False
# 9   88.984   88.642   98.642      11.0        False              False
# 10  89.107   88.980   98.980      12.0        False              False
# 11  89.069   89.020   99.020      13.0        False              False
# 12  89.065   89.025   99.025      14.0        False              False
# 13  89.055   99.055  109.055      15.0        False              False
# 14  89.179   99.179  109.179      16.0        False              False
# 15  89.475   99.475  109.475      17.0         True              False
# 16  89.526   99.526  109.526      19.0        False              False
# 17  94.526  104.526  114.526      20.0        False              False
#
#     Team_Ferrari  Team_Haas F1 Team  Team_Kick Sauber  Team_McLaren  \
# 0          False              False             False         False
# 1           True              False             False         False
# 2          False              False             False         False
# 3          False              False             False         False
# 4          False              False             False          True
# 5          False              False             False          True
# 6          False              False             False         False
# 7          False              False             False         False
# 8          False              False             False         False
# 9           True              False             False         False
# 10         False              False             False         False
# 11         False               True             False         False
# 12         False              False             False         False
# 13         False               True             False         False
# 14         False              False              True         False
# 15         False              False             False         False
# 16         False              False             False         False
# 17         False              False              True         False
#
#     Team_Mercedes  Team_RB  Team_Red Bull Racing  Team_Williams     Time
# 0           False    False                  True          False    0.000
# 1           False    False                 False          False   18.639
# 2           False    False                  True          False   13.643
# 3           False    False                 False          False   35.759
# 4           False    False                 False          False   32.007
# 5           False    False                 False          False   45.708
# 6            True    False                 False          False   39.936
# 7            True    False                 False          False   47.391
# 8           False     True                 False          False  131.986
# 9           False    False                 False          False   42.679
# 10          False    False                 False           True   88.354
# 11          False    False                 False          False  105.737
# 12          False     True                 False          False  142.168
# 13          False    False                 False          False   76.996
# 14          False    False                 False          False  144.568
# 15          False    False                 False          False  125.454
# 16          False    False                 False           True  128.238
# 17          False    False                 False          False  151.006

# %%
from sklearn.model_selection import cross_val_score, LeaveOneOut
from sklearn.ensemble import VotingRegressor
import xgboost as xgb

# # Feature engineering
# X_train['Q1_Q2_diff'] = X_train['Q1'] - X_train['Q2']
# X_train['Q2_Q3_diff'] = X_train['Q2'] - X_train['Q3']
# X_predict['Q1_Q2_diff'] = X_predict['Q1'] - X_predict['Q2']

# %%
# Initialize models
# rf = RandomForestRegressor(n_estimators=100, max_depth=5, min_samples_split=2, random_state=42)
# gb = GradientBoostingRegressor(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=42)
rf = RandomForestRegressor(n_estimators=100,random_state=10)
xgb_model = xgb.XGBRegressor(n_estimators = 100, random_state=10)
gb = GradientBoostingRegressor(n_estimators=100, random_state=10)
# xgb_model = xgb.XGBRegressor(n_estimators=50, max_depth=3, learning_rate=0.1, random_state=42, verbosity=0)

# Create ensemble
ensemble = VotingRegressor([
    ('rf', rf),
    ('gb', gb),
    ('xgb', xgb_model)
])

# Use LeaveOneOut cross-validation due to small dataset
loo = LeaveOneOut()

# Calculate cross-validation scores for each model
models = {'Random Forest': rf, 'Gradient Boosting': gb, 'XGBoost': xgb_model, 'Ensemble': ensemble}
cv_results = {}

for name, model in models.items():
    scores = cross_val_score(model, X_train, y_train['Time'], 
                            scoring='neg_mean_absolute_error',
                            cv=loo)
    mae = -scores.mean()
    cv_results[name] = mae
    print(f'{name} CV MAE: {mae:.2f} seconds')
# Out:
# Random Forest CV MAE: 24.45 seconds
# Gradient Boosting CV MAE: 25.14 seconds
# XGBoost CV MAE: 30.21 seconds
# Ensemble CV MAE: 26.39 seconds

# %%
def seconds_to_time(seconds):
    h = int(seconds // 3600)
    m = int((seconds % 3600) // 60)
    s = seconds % 60
    return f"{h:02d}:{m:02d}:{s:06.3f}"

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Standardize numerical features in X_train
numerical_features = ['Q1', 'Q2', 'Q3', 'Position']
X_train[numerical_features] = scaler.fit_transform(X_train[numerical_features])

# Standardize numerical features in X_predict using the same scaler
X_predict[numerical_features] = scaler.transform(X_predict[numerical_features])

# Standardize the target variable
y_scaler = StandardScaler()
y_train_scaled = y_scaler.fit_transform(y_train)

print('Data standardization completed.')
# Out:
# Data standardization completed.

# %%
# Modify the model training and prediction code to handle scaled data
models = {'Random Forest': rf, 'Gradient Boosting': gb, 'XGBoost': xgb_model ,'Ensemble': ensemble}
predictions = {}

for name, model in models.items():
    # Fit the model with scaled data
    model.fit(X_train, y_train_scaled.ravel())
    
    # Make predictions and inverse transform to original scale
    pred_scaled = model.predict(X_predict)
    pred = y_scaler.inverse_transform(pred_scaled.reshape(-1, 1)).ravel()

    pred_adjusted =pred
    
    
    predictions[name] = pred_adjusted
    
    # Create results DataFrame
    results = pd.DataFrame({
        'Abbreviation': driver_abbr,
        'Predicted_Race_Time_sec': pred_adjusted,
        'Predicted_Race_Time': [seconds_to_time(s) for s in pred_adjusted]
    })
    
    # Sort and display results
    results_sorted = results.sort_values('Predicted_Race_Time_sec')
    print(f"\n{name} Predictions:")
    print(results_sorted[['Abbreviation', 'Predicted_Race_Time']])
    print(f"MAE from cross-validation: {cv_results[name]:.2f} seconds")
# Out:
# Random Forest Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        00:00:07.150
# 81          PIA        00:00:14.020
# 63          RUS        00:00:15.880
# 16          LEC        00:00:23.519
# 12          ANT        00:00:23.756
# 22          TSU        00:00:25.261
# 55          SAI        00:00:27.197
# 44          HAM        00:00:27.919
# 10          GAS        00:00:41.619
# 23          ALB        00:00:44.992
# 4           NOR        00:00:47.433
# 87          BEA        00:00:54.300
# 14          ALO        00:00:55.025
# 30          LAW        00:00:57.986
# 6           HAD        00:01:01.659
# 18          STR        00:01:05.541
# 7           DOO        00:01:08.554
# 27          HUL        00:01:11.681
# 31          OCO        00:01:46.125
# 5           BOR        00:02:20.517
# MAE from cross-validation: 24.45 seconds
#
# Gradient Boosting Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        00:00:00.045
# 81          PIA        00:00:08.931
# 63          RUS        00:00:13.143
# 12          ANT        00:00:26.270
# 22          TSU        00:00:26.582
# 16          LEC        00:00:26.783
# 4           NOR        00:00:31.181
# 10          GAS        00:00:33.964
# 55          SAI        00:00:33.993
# 23          ALB        00:00:34.904
# 44          HAM        00:00:34.939
# 87          BEA        00:00:37.449
# 14          ALO        00:00:38.644
# 7           DOO        00:00:49.332
# 18          STR        00:00:50.141
# 27          HUL        00:00:55.166
# 6           HAD        00:01:08.279
# 30          LAW        00:01:10.132
# 31          OCO        00:01:47.119
# 5           BOR        00:02:25.396
# MAE from cross-validation: 25.14 seconds
#
# XGBoost Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        00:00:00.059
# 81          PIA        00:00:04.039
# 63          RUS        00:00:04.039
# 12          ANT        00:00:04.039
# 22          TSU        00:00:05.992
# 16          LEC        00:00:18.628
# 10          GAS        00:00:25.603
# 23          ALB        00:00:25.622
# 4           NOR        00:00:25.622
# 44          HAM        00:00:26.410
# 55          SAI        00:00:26.448
# 87          BEA        00:00:38.530
# 14          ALO        00:00:40.280
# 18          STR        00:00:42.293
# 27          HUL        00:00:47.529
# 7           DOO        00:00:47.894
# 6           HAD        00:00:48.755
# 30          LAW        00:00:49.278
# 31          OCO        00:01:45.650
# 5           BOR        00:02:24.590
# MAE from cross-validation: 30.21 seconds
#
# Ensemble Predictions:
#    Abbreviation Predicted_Race_Time
# 1           VER        00:00:02.418
# 81          PIA        00:00:08.997
# 63          RUS        00:00:11.021
# 12          ANT        00:00:18.022
# 22          TSU        00:00:19.278
# 16          LEC        00:00:22.977
# 55          SAI        00:00:29.213
# 44          HAM        00:00:29.756
# 10          GAS        00:00:33.728
# 4           NOR        00:00:34.745
# 23          ALB        00:00:35.172
# 87          BEA        00:00:43.426
# 14          ALO        00:00:44.650
# 18          STR        00:00:52.658
# 7           DOO        00:00:55.260
# 27          HUL        00:00:58.126
# 30          LAW        00:00:59.132
# 6           HAD        00:00:59.564
# 31          OCO        00:01:46.298
# 5           BOR        00:02:23.501
# MAE from cross-validation: 26.39 seconds

# %%
# Feature importance analysis for each model that supports it
for name, model in models.items():
    if hasattr(model, 'feature_importances_'):
        print(f"\n{name} Feature Importances:")
        importances = pd.DataFrame({
            'feature': X_train.columns,
            'importance': model.feature_importances_
        })
        print(importances.sort_values('importance', ascending=False).head(10))
# Out:
# Random Forest Feature Importances:
#                  feature  importance
# 0                     Q1    0.530341
# 3               Position    0.206748
# 2                     Q3    0.094435
# 1                     Q2    0.089449
# 7      Team_Haas F1 Team    0.028389
# 11               Team_RB    0.014160
# 13         Team_Williams    0.011816
# 10         Team_Mercedes    0.007884
# 12  Team_Red Bull Racing    0.006394
# 8       Team_Kick Sauber    0.005994
#
# Gradient Boosting Feature Importances:
#                  feature  importance
# 0                     Q1    0.685749
# 3               Position    0.074405
# 2                     Q3    0.072069
# 11               Team_RB    0.044664
# 1                     Q2    0.037268
# 10         Team_Mercedes    0.032558
# 7      Team_Haas F1 Team    0.031760
# 8       Team_Kick Sauber    0.017128
# 12  Team_Red Bull Racing    0.002400
# 4            Team_Alpine    0.000926
#
# XGBoost Feature Importances:
#                  feature  importance
# 2                     Q3    0.587554
# 7      Team_Haas F1 Team    0.174048
# 13         Team_Williams    0.095672
# 0                     Q1    0.084911
# 1                     Q2    0.023020
# 12  Team_Red Bull Racing    0.018368
# 11               Team_RB    0.007538
# 8       Team_Kick Sauber    0.004839
# 4            Team_Alpine    0.003443
# 5      Team_Aston Martin    0.000295

# %%
# Get the winner (driver with lowest predicted race time)
winner_abb = results_sorted['Abbreviation'].iloc[0]

# Get the full driver name from qualifying data
winner_data = quali_2025.results[quali_2025.results['Abbreviation'] == winner_abb]
winner_name = winner_data['FullName'].iloc[0]

print(f"And the winner of the 2025 {grand_prix} Grand Prix is {winner_name}!")
# Out:
# And the winner of the 2025 Jeddah Grand Prix is Max Verstappen!

# %%
from IPython.display import Markdown

# Get the winner (driver with lowest predicted race time)
winner_abb = results_sorted['Abbreviation'].iloc[0]

# Get the full driver name from qualifying data
winner_data = quali_2025.results[quali_2025.results['Abbreviation'] == winner_abb]
winner_name = winner_data['FullName'].iloc[0]

markdown_text = f"""## 🏆 Race Winner Prediction


### And the winner of the 2025 {grand_prix} Grand Prix is:
# 🏎️ {winner_name}"""

display(Markdown(markdown_text))
# Out:
# ## 🏆 Race Winner Prediction
#
#
# ### And the winner of the 2025 Jeddah Grand Prix is:
# # 🏎️ Max Verstappen
